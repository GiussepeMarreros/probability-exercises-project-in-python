# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO
import numpy as np
dado1 = [1,2,3,4,5,6]
dado2 = [1,2,3,4,5,6]
size =1000

exec_dado1= np.random.choice(dado1,size)
exec_dado2= np.random.choice(dado2,size)

print(exec_dado1 + exec_dado2)

mayor_7= 0
par=0

for i in range(size):
    if (exec_dado1[i] + exec_dado2[i]) > 7:
        mayor_7 += 1
    if (exec_dado1[i] + exec_dado2[i]) % 2 == 0:
        par +=1


print("Cantidad de veces que la suma de los dados son mayores a 7:",mayor_7 )
print("Cantidad de veces que la suma de los dados resulta en número par:", par)
print("la proporcion de veces que salio un numero par es:", par/size)
# Out:
# [ 9  2  8 11  6  7 11  2  7  6  9 10  6  8 11  8  5  8  5  9  5  8  7  9
#  10  7  5  6  7  7  8 12 10  8 12 10  8  2  9  8  8  8  9  9  6  9  3  6
#   7  8  9  9  8 10  8  8 10  6  9  7  7  7  6  9 11  8  6  7  4  9  8  7
#  10  9  5  4  4  3  4 10  8  8  7  4  7  4  6  6  6  8  9  6 12  5  5  7
#   7  6  7  5  6  9  6 11 10  4 11  8 12  6  8  7 12  6  8  5 11  5  2  7
#   9  4 10  6  8  8  7  5  2  9 11  6  7 11  4  6  9  8  7  8  7  8  8  6
#   2  7  7  5  8  7 11  8  6  3  3  5  7  4  9  3 10  8  9  5  6  9  9  8
#  10  9  5  6  9  9  8  7  7 10  2  6  5 11  9  6  3  7  5  8  7  9 12  9
#   8  8 12  5  6  7 12  7  6  8  2  4  6 12 11  7 11  7 11  3  7  8  8 11
#   3  8  3  7 12  5  4  9  7 10  3  9  4  7  9 10  8 12  5  8  5 10  4  6
#   6  4  6  9  7 10  9  5  7 11  7  8 10 12 10 10  8  7  3  6  5 11  7  7
#  11  7  7  3 11  4 10  6  8  6  5 11  3  9 11  5  6  8  8 10  4  5  4  6
#   4  8  6  6 10  8  8  7  6  5  5  6  6  5  8  4  8  7  9  7  4  5 10 10
#   5  8 10  6 10  4  8 10  5  6 10  4  8  7  6  2  9  7  6  7  3  8 12  7
#   7  7  4 10  9  6 11 10  9  9  3  6  9  9  8  9  7 11  9  5  6  8  9  6
#   6  9  6  6  6  8  3  6  7  7 10  6  7  7  6  7  3  4  8  5  5  7  6 11
#   8  4  9 10  6  6  8  7 11  9  5 11  5  9 12  7 11  8  5  7  3  5  3  5
#   9  6  2  7 10  7  6  8  4  4  7 12  3  4  6  4  6  8  2  9  8  4  6  3
#   9  8  8  4 12  4  6 12  6  8  7  7 11  6  9  6  6  4  6 10 10  6 10  7
#   8  9  2  6 10  5  3  7  9  5  5 11 10  6 11  4 11 11  5  6  7  5  7  7
#   7  6  7  6  4  7  7  5  8  8  7 11 11  7  8  8  7  9  7  8  4  8  9 10
#   7 12  4  5  6  9  9  9  8  8  4  3 12  7  3  5  3  6  5  5 10  6  8  6
#   9  6  6  6 10  6  9  8  8  8 10  6  7  3  2  9  5  5 10  9  6  7  9 10
#  10  4  5  3  6  6  8  6  6  9  8  6  5 10  3  4  8  7  3  3  9  4  7  9
#   6 12  7  8  4  7  9  6  2  7  8  4  5  8  5 10  7 11  4  9  5  2  9  3
#  11  7  8  4 11  8  7  7 11  6  5  5  7  9  3 12  6  8  5  7 10  4 10  7
#  10 12  7 11  6  7  3  8  5  3  7  6  8  2  3  9  7  9  7  6  7  7  5  9
#   6  8  5  7 10  7  6  3  3  7  6 11 10  5 10  8  7  6 10  6 12  5  8  5
#  12  5  7 10  6  4 12  5 12  4  6  7  9  4  8  8  6  3  8  6  8  5  3  6
#   6  9  9  4  7  5  7  4  8  3  6  6  9  3  5  9  7  5  7  3  7 10  6  9
#   3  9  6 10  9  8  4  6  8 11  9 10  7 11  3  7 11  9 10  9  6  6  8  3
#   7  3  6  9 11  6  3 11  9  4  5 10  9  8  7 11 10  8  3  8  5  7  8  6
#   5  8  5  7  7  9  5  9  9  6  7  9  4  2  2  6  7  5  6  5  7  7  2  8
#   7 12  7  7  4  8  5  2  7  7  7  4  9  7  6  5 11  2  7  9 12  5  7  6
#  10  8  4  5  7  8  4  7 10  3  5  9  5  5  2  9  8  9  9  7  9  9 11 11
#   7  7 10 10 10  4  7  7  7  6 10  7  8 10  8  8 10 12  6  7  6 10  2  8
#   9  3  5  9  8  3  8  8 11  5  8  5  7  9  8  7  8  7  5  9  6  7 10  9
#   6  6 11 10  7  8  9  9  9  6  9  3  7  4  6  8 11  5  7  4 11  9  7  6
#   5  8  9  7  5  7  5  9  4 11  6  6  4  8  9  6  3  8  7 10  6  5  8 10
#   7  4  7  3  9  7  4 12  3  5  9 10  7  4  9  8 10  9  2  6  5 11 12  5
#  12  6  5 10  7  7 11 12  5 10  5  3 11  5  7  9  6  7 11  5  6  9  9  4
#  12  6  6  7  9 10  9  7  6  5  8  6  6 10  7  7]
# Cantidad de veces que la suma de los dados son mayores a 7: 429
# Cantidad de veces que la suma de los dados resulta en número par: 488
# la proporcion de veces que salio un numero par es: 0.488

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
box =["r"]*20 + ["v"]*30 + ["b"]*10
print(box)

result=[]
trial=1000
count1=0
count2=0

for i in range(trial):
    result.append(np.random.choice(box,5,replace=True))

for i in range(len(result)):
    if ((np.array(result[i]) =="b").sum()) == 3 and ((np.array(result[i]) =="r").sum()) == 2:
        count1 +=1
        print(result[i])
print("cantidad de veces que salieron 3 blancas y 2 rojas:",count1)
print("la probabilidad de sacar 3 blancas y 2 rojas en 1000 intentos es:",count1/1000)

for i in range(len(result)):
    if ((np.array(result[i]) =="b").sum()) == 5 or ((np.array(result[i]) =="r").sum()) == 5 or ((np.array(result[i]) =="v").sum()) == 5:
        count2 +=1
        print(result[i])
print("cantidad de veces que salieron todas del mismo color:",count2)
print("la probabilidad de sacar todas del mismo color en 1000 intentos es:",count2/1000)
# Out:
# ['r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
# ['b' 'b' 'r' 'b' 'r']
# ['b' 'r' 'b' 'b' 'r']
# ['b' 'r' 'b' 'b' 'r']
# ['b' 'r' 'b' 'b' 'r']
# cantidad de veces que salieron 3 blancas y 2 rojas: 4
# la probabilidad de sacar 3 blancas y 2 rojas en 1000 intentos es: 0.004
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['r' 'r' 'r' 'r' 'r']
# ['r' 'r' 'r' 'r' 'r']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['r' 'r' 'r' 'r' 'r']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['r' 'r' 'r' 'r' 'r']
# ['v' 'v' 'v' 'v' 'v']
# ['r' 'r' 'r' 'r' 'r']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# ['v' 'v' 'v' 'v' 'v']
# cantidad de veces que salieron todas del mismo color: 52
# la probabilidad de sacar todas del mismo color en 1000 intentos es: 0.052
